# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv("bitstampUSD_1-min_data_2012-01-01_to_2020-09-14.csv.zip")

# %%
df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df.isna().sum()
# Out:
# Timestamp                  0
# Open                 1241716
# High                 1241716
# Low                  1241716
# Close                1241716
# Volume_(BTC)         1241716
# Volume_(Currency)    1241716
# Weighted_Price       1241716
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %%
df.Timestamp = [datetime.fromtimestamp(x) for x in df.Timestamp]

# %%
# Changing columns name
df.rename(columns = {"Timestamp":"Date"},inplace=True)

# %%
# setting Date as index on df 
df.set_index("Date")
# Out:
#                          Open      High       Low     Close  Volume_(BTC)  \
# Date
# 2011-12-31 08:52:00      4.39      4.39      4.39      4.39      0.455581
# 2011-12-31 08:53:00       NaN       NaN       NaN       NaN           NaN
# 2011-12-31 08:54:00       NaN       NaN       NaN       NaN           NaN
# 2011-12-31 08:55:00       NaN       NaN       NaN       NaN           NaN
# 2011-12-31 08:56:00       NaN       NaN       NaN       NaN           NaN
# ...                       ...       ...       ...       ...           ...
# 2020-09-14 01:56:00  10324.35  10325.89  10324.35  10325.89      0.081143
# 2020-09-14 01:57:00  10331.41  10331.97  10326.68  10331.97      0.572817
# 2020-09-14 01:58:00  10327.20  10331.47  10321.33  10331.47      2.489909
# 2020-09-14 01:59:00  10330.02  10334.78  10328.64  10334.78      4.572660
# 2020-09-14 02:00:00  10338.82  10338.82  10332.37  10332.37      1.292006
#
#                      Volume_(Currency)  Weighted_Price
# Date
# ...

# %%
data = pd.read_csv("stock_index-Copy1.sentiment.csv")
data
# Out:
#             Date   Bullish   Neutral   Bearish     Total  \
# 0     2020-11-19  0.443515  0.292887  0.263598  1.000000
# 1     2020-11-12  0.558376  0.192893  0.248731  1.000000
# 2     2020-11-05  0.379630  0.305556  0.314815  1.000001
# 3     2020-10-29  0.352941  0.294118  0.352941  1.000000
# 4     2020-10-22  0.357466  0.312217  0.330317  1.000000
# ...          ...       ...       ...       ...       ...
# 1736  1987-08-07  0.560000  0.150000  0.290000  1.000000
# 1737  1987-07-31  0.260000  0.480000  0.260000  1.000000
# 1738  1987-07-24  0.360000  0.500000  0.140000  1.000000
# 1739  1987-07-17       NaN       NaN       NaN       NaN
# 1740  1987-06-26       NaN       NaN       NaN       NaN
#
#       Bullish 8-Week Mov Avg  Bull-Bear Spread  Bullish Average  \
# 0                   0.381194          0.179917         0.379215
# 1                   0.356872          0.309645         0.379215
# 2                   0.327100          0.064815         0.379215
# ...

# %%
# converting Date object to datetime
data.Date = pd.to_datetime(data.Date)

# %%
# Setting Date as index
data.set_index("Date")
# Out:
#              Bullish   Neutral   Bearish     Total  Bullish 8-Week Mov Avg  \
# Date
# 2020-11-19  0.443515  0.292887  0.263598  1.000000                0.381194
# 2020-11-12  0.558376  0.192893  0.248731  1.000000                0.356872
# 2020-11-05  0.379630  0.305556  0.314815  1.000001                0.327100
# 2020-10-29  0.352941  0.294118  0.352941  1.000000                0.309285
# 2020-10-22  0.357466  0.312217  0.330317  1.000000                0.303670
# ...              ...       ...       ...       ...                     ...
# 1987-08-07  0.560000  0.150000  0.290000  1.000000                     NaN
# 1987-07-31  0.260000  0.480000  0.260000  1.000000                     NaN
# 1987-07-24  0.360000  0.500000  0.140000  1.000000                     NaN
# 1987-07-17       NaN       NaN       NaN       NaN                     NaN
# 1987-06-26       NaN       NaN       NaN       NaN                     NaN
#
# ...

# %%
# Sorting The value asceninglingly, so they have index is sorted in the same way.
data.sort_values(by="Date",ascending=True,inplace = True)
data.head()
# Out:
#            Date  Bullish  Neutral  Bearish  Total  Bullish 8-Week Mov Avg  \
# 1740 1987-06-26      NaN      NaN      NaN    NaN                     NaN
# 1739 1987-07-17      NaN      NaN      NaN    NaN                     NaN
# 1738 1987-07-24     0.36     0.50     0.14    1.0                     NaN
# 1737 1987-07-31     0.26     0.48     0.26    1.0                     NaN
# 1736 1987-08-07     0.56     0.15     0.29    1.0                     NaN
#
#       Bull-Bear Spread  Bullish Average  Bullish Average + St. Dev  \
# 1740               NaN         0.386014                   0.489178
# 1739               NaN         0.386014                   0.489178
# 1738              0.22         0.386014                   0.489178
# 1737              0.00         0.386014                   0.489178
# 1736              0.27         0.386014                   0.489178
#
#       Bullish Average - St. Dev  S&P 500 Weekly High  S&P 500 Weekly Low  \
# ...

# %%
df2 = df.copy()

# %%
df2
# Out:
#                        Date      Open      High       Low     Close  \
# 0       2011-12-31 08:52:00      4.39      4.39      4.39      4.39
# 1       2011-12-31 08:53:00       NaN       NaN       NaN       NaN
# 2       2011-12-31 08:54:00       NaN       NaN       NaN       NaN
# 3       2011-12-31 08:55:00       NaN       NaN       NaN       NaN
# 4       2011-12-31 08:56:00       NaN       NaN       NaN       NaN
# ...                     ...       ...       ...       ...       ...
# 4572252 2020-09-14 01:56:00  10324.35  10325.89  10324.35  10325.89
# 4572253 2020-09-14 01:57:00  10331.41  10331.97  10326.68  10331.97
# 4572254 2020-09-14 01:58:00  10327.20  10331.47  10321.33  10331.47
# 4572255 2020-09-14 01:59:00  10330.02  10334.78  10328.64  10334.78
# 4572256 2020-09-14 02:00:00  10338.82  10338.82  10332.37  10332.37
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
df2
# Out:
#                        Date      Open      High       Low     Close  \
# 0       2011-12-31 08:52:00      4.39      4.39      4.39      4.39
# 1       2011-12-31 08:53:00       NaN       NaN       NaN       NaN
# 2       2011-12-31 08:54:00       NaN       NaN       NaN       NaN
# 3       2011-12-31 08:55:00       NaN       NaN       NaN       NaN
# 4       2011-12-31 08:56:00       NaN       NaN       NaN       NaN
# ...                     ...       ...       ...       ...       ...
# 4572252 2020-09-14 01:56:00  10324.35  10325.89  10324.35  10325.89
# 4572253 2020-09-14 01:57:00  10331.41  10331.97  10326.68  10331.97
# 4572254 2020-09-14 01:58:00  10327.20  10331.47  10321.33  10331.47
# 4572255 2020-09-14 01:59:00  10330.02  10334.78  10328.64  10334.78
# 4572256 2020-09-14 02:00:00  10338.82  10338.82  10332.37  10332.37
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
data.isnull()
# Out:
#        Date  Bullish  Neutral  Bearish  Total  Bullish 8-Week Mov Avg  \
# 1740  False     True     True     True   True                    True
# 1739  False     True     True     True   True                    True
# 1738  False    False    False    False  False                    True
# 1737  False    False    False    False  False                    True
# 1736  False    False    False    False  False                    True
# ...     ...      ...      ...      ...    ...                     ...
# 4     False    False    False    False  False                   False
# 3     False    False    False    False  False                   False
# 2     False    False    False    False  False                   False
# 1     False    False    False    False  False                   False
# 0     False    False    False    False  False                   False
#
#       Bull-Bear Spread  Bullish Average  Bullish Average + St. Dev  \
# ...

# %%
data2 = data.copy()

# %%
data.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Date                       0
# Open                 1241716
# High                 1241716
# Low                  1241716
# Close                1241716
# Volume_(BTC)         1241716
# Volume_(Currency)    1241716
# Weighted_Price       1241716
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                        Date      Open      High       Low     Close  \
# 0       2011-12-31 08:52:00      4.39      4.39      4.39      4.39
# 478     2011-12-31 16:50:00      4.39      4.39      4.39      4.39
# 547     2011-12-31 17:59:00      4.50      4.57      4.50      4.57
# 548     2011-12-31 18:00:00      4.58      4.58      4.58      4.58
# 1224    2012-01-01 05:16:00      4.58      4.58      4.58      4.58
# ...                     ...       ...       ...       ...       ...
# 4572252 2020-09-14 01:56:00  10324.35  10325.89  10324.35  10325.89
# 4572253 2020-09-14 01:57:00  10331.41  10331.97  10326.68  10331.97
# 4572254 2020-09-14 01:58:00  10327.20  10331.47  10321.33  10331.47
# 4572255 2020-09-14 01:59:00  10330.02  10334.78  10328.64  10334.78
# 4572256 2020-09-14 02:00:00  10338.82  10338.82  10332.37  10332.37
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0            0.455581           2.000000        4.390000
# ...

# %%
# getting the bull and bear columns
bnb = data[["Date","Bullish","Neutral","Bearish"]]

# %%
bnb
# Out:
#            Date   Bullish   Neutral   Bearish
# 1731 1987-09-11  0.500000  0.230000  0.270000
# 1730 1987-09-18  0.600000  0.290000  0.110000
# 1729 1987-09-25  0.530000  0.170000  0.300000
# 1728 1987-10-02  0.440000  0.260000  0.300000
# 1727 1987-10-09  0.460000  0.390000  0.150000
# ...         ...       ...       ...       ...
# 4    2020-10-22  0.357466  0.312217  0.330317
# 3    2020-10-29  0.352941  0.294118  0.352941
# 2    2020-11-05  0.379630  0.305556  0.314815
# 1    2020-11-12  0.558376  0.192893  0.248731
# 0    2020-11-19  0.443515  0.292887  0.263598
#
# [1724 rows x 4 columns]

# %%
df.Open.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
df3 = df.copy()

# %%
df3.set_index("Date", inplace=True)

# %%
bnb2 = bnb.copy()

# %%
bnb = bnb.reset_index()

# %%
pd.options.display.max_rows = 200
pd.options.display.min_rows = 200

# %%
bnb.iloc[1250:]
# Out:
#       index       Date   Bullish   Neutral   Bearish
# 1250    473 2011-10-27  0.430000  0.320000  0.250000
# 1251    472 2011-11-03  0.401800  0.302000  0.296200
# 1252    471 2011-11-10  0.447300  0.307000  0.245600
# 1253    470 2011-11-17  0.419300  0.270100  0.310400
# 1254    469 2011-11-24  0.327100  0.290100  0.382700
# 1255    468 2011-12-01  0.330400  0.275300  0.394200
# 1256    467 2011-12-08  0.385700  0.266600  0.347600
# 1257    466 2011-12-15  0.401800  0.261600  0.336400
# 1258    465 2011-12-22  0.337250  0.380390  0.282350
# 1259    464 2011-12-29  0.406000  0.285700  0.308270
# 1260    463 2012-01-05  0.488800  0.339500  0.171600
# 1261    462 2012-01-12  0.491400  0.336800  0.171800
# 1262    461 2012-01-19  0.472300  0.291500  0.236100
# 1263    460 2012-01-26  0.483974  0.326920  0.189100
# 1264    459 2012-02-02  0.438060  0.311170  0.250750
# 1265    458 2012-02-09  0.516430  0.281690  0.201870
# 1266    457 2012-02-16  0.427130  0.306530  0.266330
# ...

# %%
sent = bnb.loc[1260:]

# %%
btc = df.loc[6828:]

# %%
sent = sent.loc[:1713]

# %%
btc.loc[btc.Date == "2020-09-10"].index
# Out:
# Int64Index([4566376], dtype='int64')

# %%
btc = btc.loc[:4567815]

# %%
pd.concat([btc,sent])
# Out:
#                      Date  Open  High   Low  Close  Volume_(BTC)  \
# 6828  2012-01-05 02:40:00  5.72  5.72  5.72   5.72      5.000000
# 6960  2012-01-05 04:52:00  5.75  5.75  5.75   5.75      5.200000
# 7167  2012-01-05 08:19:00  5.75  5.79  5.75   5.79     14.800000
# 7266  2012-01-05 09:58:00  6.00  6.00  6.00   6.00      2.236667
# 7271  2012-01-05 10:03:00  6.00  6.00  6.00   6.00      0.168483
# 7316  2012-01-05 10:48:00  6.15  6.15  6.15   6.15     10.000000
# 7336  2012-01-05 11:08:00  6.19  6.19  6.19   6.19      0.571890
# 7338  2012-01-05 11:10:00  6.19  6.23  6.19   6.23     16.000000
# 7376  2012-01-05 11:48:00  6.23  6.25  6.23   6.25     14.000000
# 7408  2012-01-05 12:20:00  6.46  6.46  6.46   6.46      0.773994
# 7409  2012-01-05 12:21:00  6.46  6.46  6.46   6.46      0.178019
# 7416  2012-01-05 12:28:00  6.43  6.43  6.43   6.43      0.311042
# 7515  2012-01-05 14:07:00  6.44  6.44  6.44   6.44      0.310559
# ...

# %%
btc2 = btc.copy()

# %%
btc = btc.reset_index()

# %%
btc2 = btc.copy()

# %%
btc2.reset_index(inplace=True)
btc2
# Out:
#          level_0    index                Date      Open      High       Low  \
# 0              0     6828 2012-01-05 02:40:00      5.72      5.72      5.72
# 1              1     6960 2012-01-05 04:52:00      5.75      5.75      5.75
# 2              2     7167 2012-01-05 08:19:00      5.75      5.79      5.75
# 3              3     7266 2012-01-05 09:58:00      6.00      6.00      6.00
# 4              4     7271 2012-01-05 10:03:00      6.00      6.00      6.00
# 5              5     7316 2012-01-05 10:48:00      6.15      6.15      6.15
# 6              6     7336 2012-01-05 11:08:00      6.19      6.19      6.19
# 7              7     7338 2012-01-05 11:10:00      6.19      6.23      6.19
# 8              8     7376 2012-01-05 11:48:00      6.23      6.25      6.23
# 9              9     7408 2012-01-05 12:20:00      6.46      6.46      6.46
# 10            10     7409 2012-01-05 12:21:00      6.46      6.46      6.46
# ...

# %%
btc2['Date'] = pd.to_datetime(btc2['Date']).dt.floor('d')

# %%
btc2.set_index("Date",inplace=True)

# %%
btc = btc2

# %%
sent.set_index("Date",inplace=True)

# %%
bitcoin = btc.merge(sent, how = "outer", on = "Date",suffixes = ("btc","sent"))

# %%
bitcoin
# Out:
#               level_0   indexbtc      Open      High       Low     Close  \
# Date
# 2012-01-05        0.0     6828.0      5.72      5.72      5.72      5.72
# 2012-01-05        1.0     6960.0      5.75      5.75      5.75      5.75
# 2012-01-05        2.0     7167.0      5.75      5.79      5.75      5.79
# 2012-01-05        3.0     7266.0      6.00      6.00      6.00      6.00
# 2012-01-05        4.0     7271.0      6.00      6.00      6.00      6.00
# 2012-01-05        5.0     7316.0      6.15      6.15      6.15      6.15
# 2012-01-05        6.0     7336.0      6.19      6.19      6.19      6.19
# 2012-01-05        7.0     7338.0      6.19      6.23      6.19      6.23
# 2012-01-05        8.0     7376.0      6.23      6.25      6.23      6.25
# 2012-01-05        9.0     7408.0      6.46      6.46      6.46      6.46
# 2012-01-05       10.0     7409.0      6.46      6.46      6.46      6.46
# 2012-01-05       11.0     7416.0      6.43      6.43      6.43      6.43
# ...

# %%
new_df = bitcoin.groupby("Date")[["Open","High","Low","Close","Volume_(BTC)","Volume_(Currency)","Weighted_Price"]].mean()

# %%
dct = {"Open":"mean", "High":"mean", "Low":"mean", "Close":"mean", "Weighted_Price":"mean",
       "Volume_(Currency)":"sum", "Volume_(BTC)":"sum"}

# %%
# 2020-09-10 volume btc = 10345
# Kursen för btc var då ca 10000 USD
# I dollar var då volymen 10000*10345 = 100 000 000 USD

# %%
new_df_test = bitcoin.groupby("Date")[["Open","High","Low","Close","Volume_(BTC)","Volume_(Currency)","Weighted_Price"]].agg(dct)
new_df_test
# Out:
#                     Open          High           Low         Close  \
# Date
# 2012-01-05      6.190625      6.196875      6.190625      6.196875
# 2012-01-06      6.471053      6.478421      6.471053      6.478421
# 2012-01-07      6.800000      6.800000      6.800000      6.800000
# 2012-01-08      6.900000      6.900000      6.900000      6.900000
# 2012-01-09      6.595405      6.595405      6.592973      6.592973
# 2012-01-10      6.603000      6.603000      6.603000      6.603000
# 2012-01-11      7.119583      7.121875      7.119583      7.121875
# 2012-01-12      7.062500      7.062500      7.062500      7.062500
# 2012-01-13      6.980645      6.996452      6.951613      6.971935
# 2012-01-14      6.436364      6.436364      6.427273      6.427273
# 2012-01-15      7.150000      7.150000      7.150000      7.150000
# 2012-01-16      6.714286      6.714286      6.714286      6.714286
# 2012-01-17      6.160870      6.160870      6.147826      6.147826
# ...

# %%
bit = new_df.merge(sent,how="outer", on = "Date", suffixes = ("new_df","sent"))
bit
# Out:
#                     Open          High           Low         Close  \
# Date
# 2012-01-05      6.190625      6.196875      6.190625      6.196875
# 2012-01-06      6.471053      6.478421      6.471053      6.478421
# 2012-01-07      6.800000      6.800000      6.800000      6.800000
# 2012-01-08      6.900000      6.900000      6.900000      6.900000
# 2012-01-09      6.595405      6.595405      6.592973      6.592973
# 2012-01-10      6.603000      6.603000      6.603000      6.603000
# 2012-01-11      7.119583      7.121875      7.119583      7.121875
# 2012-01-12      7.062500      7.062500      7.062500      7.062500
# 2012-01-13      6.980645      6.996452      6.951613      6.971935
# 2012-01-14      6.436364      6.436364      6.427273      6.427273
# 2012-01-15      7.150000      7.150000      7.150000      7.150000
# 2012-01-16      6.714286      6.714286      6.714286      6.714286
# 2012-01-17      6.160870      6.160870      6.147826      6.147826
# ...

# %%
bit2 = bit.copy()
bit2
# Out:
#                     Open          High           Low         Close  \
# Date
# 2012-01-05      6.190625      6.196875      6.190625      6.196875
# 2012-01-06      6.471053      6.478421      6.471053      6.478421
# 2012-01-07      6.800000      6.800000      6.800000      6.800000
# 2012-01-08      6.900000      6.900000      6.900000      6.900000
# 2012-01-09      6.595405      6.595405      6.592973      6.592973
# 2012-01-10      6.603000      6.603000      6.603000      6.603000
# 2012-01-11      7.119583      7.121875      7.119583      7.121875
# 2012-01-12      7.062500      7.062500      7.062500      7.062500
# 2012-01-13      6.980645      6.996452      6.951613      6.971935
# 2012-01-14      6.436364      6.436364      6.427273      6.427273
# 2012-01-15      7.150000      7.150000      7.150000      7.150000
# 2012-01-16      6.714286      6.714286      6.714286      6.714286
# 2012-01-17      6.160870      6.160870      6.147826      6.147826
# ...

# %%
bit2.groupby("Date").Open.mean()
# Out:
# Date
# 2012-01-05        6.190625
# 2012-01-06        6.471053
# 2012-01-07        6.800000
# 2012-01-08        6.900000
# 2012-01-09        6.595405
# 2012-01-10        6.603000
# 2012-01-11        7.119583
# 2012-01-12        7.062500
# 2012-01-13        6.980645
# 2012-01-14        6.436364
# 2012-01-15        7.150000
# 2012-01-16        6.714286
# 2012-01-17        6.160870
# 2012-01-18        6.232703
# 2012-01-19        6.216364
# 2012-01-20        6.702308
# 2012-01-21        6.386000
# 2012-01-22        6.485000
# 2012-01-23        6.407500
# 2012-01-24        6.495556
# 2012-01-25        6.284444
# 2012-01-26        6.220000
# 2012-01-27        5.646207
# 2012-01-28        4.910000
# 2012-01-29        5.745000
# 2012-01-30        5.540000
# 2012-01-31        5.611463
# 2012-02-01        5.748750
# 2012-02-02        6.171667
# 2012-02-03        6.207333
# 2012-02-04        6.094375
# 2012-02-05        5.861364
# 2012-02-06        5.526250
# 2012-02-07        5.663529
# ...

# %%
bit2["MA Open"] = bit2["Open"].rolling(7).mean()

# %%
bit.head()
# Out:
#                 Open      High       Low     Close  Volume_(BTC)  \
# Date
# 2012-01-05  6.190625  6.196875  6.190625  6.196875      4.415017
# 2012-01-06  6.471053  6.478421  6.471053  6.478421      3.054964
# 2012-01-07  6.800000  6.800000  6.800000  6.800000      0.295858
# 2012-01-08  6.900000  6.900000  6.900000  6.900000      4.000000
# 2012-01-09  6.595405  6.595405  6.592973  6.592973      1.834306
#
#             Volume_(Currency)  Weighted_Price  index  Bullish  Neutral  \
# Date
# 2012-01-05          26.708108        6.194167  463.0   0.4888   0.3395
# 2012-01-06          20.168961        6.473999    NaN      NaN      NaN
# 2012-01-07           2.011834        6.800000    NaN      NaN      NaN
# 2012-01-08          27.600000        6.900000    NaN      NaN      NaN
# 2012-01-09          12.163371        6.594046    NaN      NaN      NaN
#
#             Bearish
# Date
# 2012-01-05   0.1716
# 2012-01-06      NaN
# 2012-01-07      NaN
# 2012-01-08      NaN
# ...

# %%
bly = bit.rolling(7,min_periods=1).mean()
bly
# Out:
#                     Open          High           Low         Close  \
# Date
# 2012-01-05      6.190625      6.196875      6.190625      6.196875
# 2012-01-06      6.330839      6.337648      6.330839      6.337648
# 2012-01-07      6.487226      6.491765      6.487226      6.491765
# 2012-01-08      6.590419      6.593824      6.590419      6.593824
# 2012-01-09      6.591417      6.594140      6.590930      6.593654
# 2012-01-10      6.593347      6.595617      6.592942      6.595212
# 2012-01-11      6.668524      6.670797      6.668176      6.670449
# 2012-01-12      6.793077      6.794457      6.792730      6.794110
# 2012-01-13      6.865876      6.868462      6.861381      6.864612
# 2012-01-14      6.813928      6.816514      6.808135      6.811365
# 2012-01-15      6.849643      6.852228      6.843849      6.847079
# 2012-01-16      6.866625      6.869211      6.861179      6.864410
# 2012-01-17      6.803464      6.806049      6.796154      6.799385
# ...

# %%
bly = bit.rolling(7,min_periods=1).mean()
bly
# Out:
#                     Open          High           Low         Close  \
# Date
# 2012-01-05      6.190625      6.196875      6.190625      6.196875
# 2012-01-06      6.330839      6.337648      6.330839      6.337648
# 2012-01-07      6.487226      6.491765      6.487226      6.491765
# 2012-01-08      6.590419      6.593824      6.590419      6.593824
# 2012-01-09      6.591417      6.594140      6.590930      6.593654
# 2012-01-10      6.593347      6.595617      6.592942      6.595212
# 2012-01-11      6.668524      6.670797      6.668176      6.670449
# 2012-01-12      6.793077      6.794457      6.792730      6.794110
# 2012-01-13      6.865876      6.868462      6.861381      6.864612
# 2012-01-14      6.813928      6.816514      6.808135      6.811365
# 2012-01-15      6.849643      6.852228      6.843849      6.847079
# 2012-01-16      6.866625      6.869211      6.861179      6.864410
# 2012-01-17      6.803464      6.806049      6.796154      6.799385
# ...

# %%
bit[["Bullish","Neutral","Bearish"]] = bly[["Bullish","Neutral","Bearish"]]

# %%
bit[["Bullish","Neutral","Bearish"]]
# Out:
#              Bullish   Neutral   Bearish
# Date
# 2012-01-05  0.488800  0.339500  0.171600
# 2012-01-06  0.488800  0.339500  0.171600
# 2012-01-07  0.488800  0.339500  0.171600
# 2012-01-08  0.488800  0.339500  0.171600
# 2012-01-09  0.488800  0.339500  0.171600
# 2012-01-10  0.488800  0.339500  0.171600
# 2012-01-11  0.488800  0.339500  0.171600
# 2012-01-12  0.491400  0.336800  0.171800
# 2012-01-13  0.491400  0.336800  0.171800
# 2012-01-14  0.491400  0.336800  0.171800
# 2012-01-15  0.491400  0.336800  0.171800
# 2012-01-16  0.491400  0.336800  0.171800
# 2012-01-17  0.491400  0.336800  0.171800
# 2012-01-18  0.491400  0.336800  0.171800
# 2012-01-19  0.472300  0.291500  0.236100
# 2012-01-20  0.472300  0.291500  0.236100
# 2012-01-21  0.472300  0.291500  0.236100
# 2012-01-22  0.472300  0.291500  0.236100
# 2012-01-23  0.472300  0.291500  0.236100
# 2012-01-24  0.472300  0.291500  0.236100
# 2012-01-25  0.472300  0.291500  0.236100
# 2012-01-26  0.483974  0.326920  0.189100
# ...

# %%
bit[["Open","High","Low","Close"]] = round(bit[["Open","High","Low","Close"]],2)

# %%
bit[["Bullish","Neutral","Bearish"]] = round(bit[["Bullish","Neutral","Bearish"]],2)

# %%
#bit[["Bullish","Bearish"]].plot(figsize=(12,6))

# %%
bit.drop(columns="index",inplace=True)

# %%
two_scaler = bit[["Open","Bullish","Neutral","Bearish"]].copy()

# %%
two_scaler
# Out:
#                 Open  Bullish  Neutral  Bearish
# Date
# 2012-01-05      6.19     0.49     0.34     0.17
# 2012-01-06      6.47     0.49     0.34     0.17
# 2012-01-07      6.80     0.49     0.34     0.17
# 2012-01-08      6.90     0.49     0.34     0.17
# 2012-01-09      6.60     0.49     0.34     0.17
# 2012-01-10      6.60     0.49     0.34     0.17
# 2012-01-11      7.12     0.49     0.34     0.17
# 2012-01-12      7.06     0.49     0.34     0.17
# 2012-01-13      6.98     0.49     0.34     0.17
# 2012-01-14      6.44     0.49     0.34     0.17
# 2012-01-15      7.15     0.49     0.34     0.17
# 2012-01-16      6.71     0.49     0.34     0.17
# 2012-01-17      6.16     0.49     0.34     0.17
# 2012-01-18      6.23     0.49     0.34     0.17
# 2012-01-19      6.22     0.47     0.29     0.24
# 2012-01-20      6.70     0.47     0.29     0.24
# 2012-01-21      6.39     0.47     0.29     0.24
# 2012-01-22      6.48     0.47     0.29     0.24
# ...

# %% [markdown]
# ## Scaling the two datasets

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

test_scaled = pd.DataFrame(scaler.fit_transform(two_scaler), columns= two_scaler.columns)

# %%
test_scaled
# Out:
#           Open   Bullish   Neutral   Bearish
# 0     0.000097  0.738095  0.500000  0.051282
# 1     0.000111  0.738095  0.500000  0.051282
# 2     0.000129  0.738095  0.500000  0.051282
# 3     0.000134  0.738095  0.500000  0.051282
# 4     0.000118  0.738095  0.500000  0.051282
# 5     0.000118  0.738095  0.500000  0.051282
# 6     0.000145  0.738095  0.500000  0.051282
# 7     0.000142  0.738095  0.500000  0.051282
# 8     0.000138  0.738095  0.500000  0.051282
# 9     0.000110  0.738095  0.500000  0.051282
# 10    0.000147  0.738095  0.500000  0.051282
# 11    0.000124  0.738095  0.500000  0.051282
# 12    0.000095  0.738095  0.500000  0.051282
# 13    0.000099  0.738095  0.500000  0.051282
# 14    0.000098  0.690476  0.368421  0.230769
# 15    0.000123  0.690476  0.368421  0.230769
# 16    0.000107  0.690476  0.368421  0.230769
# 17    0.000112  0.690476  0.368421  0.230769
# 18    0.000108  0.690476  0.368421  0.230769
# 19    0.000113  0.690476  0.368421  0.230769
# ...

# %%
test_scaled.reset_index(inplace = True)

# %%
# Pris och volym

# %%
bit2.reset_index(inplace=True)

# %%
test_scaled["Date"] = bit2.Date

# %%
test_scaled.set_index("Date",inplace=True)

# %% [markdown]
# ## Plotting

# %%
new_df_test.head()
# Out:
#                 Open      High       Low     Close  Weighted_Price  \
# Date
# 2012-01-05  6.190625  6.196875  6.190625  6.196875        6.194167
# 2012-01-06  6.471053  6.478421  6.471053  6.478421        6.473999
# 2012-01-07  6.800000  6.800000  6.800000  6.800000        6.800000
# 2012-01-08  6.900000  6.900000  6.900000  6.900000        6.900000
# 2012-01-09  6.595405  6.595405  6.592973  6.592973        6.594046
#
#             Volume_(Currency)  Volume_(BTC)
# Date
# 2012-01-05         427.329730     70.640269
# 2012-01-06         383.210255     58.044307
# 2012-01-07           2.011834      0.295858
# 2012-01-08          27.600000      4.000000
# 2012-01-09         450.044720     67.869323

# %%
bit[["Volume_(BTC)","Volume_(Currency)"]] = new_df_test[["Volume_(BTC)","Volume_(Currency)"]]

# %%
fig = plt.figure(figsize=(18,8))
axes = fig.add_axes([0,0,0.8,0.8])

axes.plot(test_scaled["Open"], label = "Bitcoin index")
axes.plot(test_scaled["Bullish"],label = "Bull",c="orange",)
axes.set_xlabel("Year")
axes.set_ylabel("Scaled")
axes.set_title("Market Sentiment And Bitcoin Index")

plt.legend(loc =2 , frameon = False);

# %%
fig = plt.figure(figsize=(18,8))
axes = fig.add_axes([0,0,0.8,0.8])

axes.plot(test_scaled["Open"], label = "Bitcoin index")
axes.plot(test_scaled["Bearish"],label = "Bear",c="r",)
axes.set_xlabel("Year")
axes.set_ylabel("Scale")
axes.set_title("Bear Market Sentiment And Bitcoin Index")

plt.legend(loc =2 , frameon = False)

plt.show()

# %%
fig2 = plt.figure(figsize=(18,8))
ax = fig2.add_axes([0,0,0.8,0.8])

ax.plot(bit["Bullish"],c = "blue")
ax.plot(bit["Bearish"],c="r")
ax.set_xlabel("Year")
ax.set_ylabel("Procent")
ax.set_title("Sentiment Data Comparison")



plt.show()

# %% [markdown]
# ## scatter

# %%
import numpy as np

# %%
corrmat = bit.corr()
corrmat
# Out:
#                        Open      High       Low     Close  Volume_(BTC)  \
# Open               1.000000  1.000000  1.000000  1.000000      0.030554
# High               1.000000  1.000000  0.999999  1.000000      0.030774
# Low                1.000000  0.999999  1.000000  1.000000      0.030305
# Close              1.000000  1.000000  1.000000  1.000000      0.030551
# Volume_(BTC)       0.030554  0.030774  0.030305  0.030551      1.000000
# Volume_(Currency)  0.753053  0.753373  0.752680  0.753050      0.351355
# Weighted_Price     1.000000  1.000000  1.000000  1.000000      0.030530
# Bullish           -0.036016 -0.035875 -0.036188 -0.036013      0.103935
# Neutral           -0.183596 -0.183643 -0.183546 -0.183601     -0.007924
# Bearish            0.187255  0.187152  0.187384  0.187256     -0.099935
#
#                    Volume_(Currency)  Weighted_Price   Bullish   Neutral  \
# Open                        0.753053        1.000000 -0.036016 -0.183596
# ...

# %%
figer,axi  = plt.subplots(figsize = (14,10))

mask = np.zeros_like(corrmat)
mask[np.triu_indices_from(mask)] = True

# To mask we need to pass to mask param!

sns.heatmap(corrmat, mask=mask,annot=True)

# use this code if value error palceing
#bottom, top = ax.get_ylim()
#ax.set_ylim(bottom+0.5,top-0.5)

sns.heatmap(corrmat,annot= True);

# %%
dat = bit.copy()

# %%
dat.reset_index(inplace=True)

# %%
sns.regplot(data=dat,x="Volume_(BTC)", y="Volume_(Currency)")
# Out:
# <AxesSubplot:xlabel='Volume_(BTC)', ylabel='Volume_(Currency)'>

# %%
sns.jointplot(x = test_scaled["Open"], y = test_scaled["Bullish"],kind = "kde");

# %%
sns.scatterplot(x = bit["Open"], y = bit["Bullish"])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Bullish'>
